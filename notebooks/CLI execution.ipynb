# %%
definition = """
transform: 
  settings: &settings
    output: output/
    rules: data/rules.json                                                                                                                                        
  data:
    - input: data/part1
      <<: *settings
"""
with open('config.yml','w') as f:
    f.write(definition)

# %%
# !coconnect etl --config config.yml
# Out:
# 2022-03-09 17:05:49 - LocalDataCollection - INFO - DataCollection Object Created
# 2022-03-09 17:05:49 - LocalDataCollection - INFO - Registering  Demographics.csv [<coconnect.io.common.DataBrick object at 0x114a84cd0>]
# 2022-03-09 17:05:49 - LocalDataCollection - INFO - Registering  GP_Records.csv [<coconnect.io.common.DataBrick object at 0x114a84e20>]
# 2022-03-09 17:05:49 - LocalDataCollection - INFO - Registering  Hospital_Visit.csv [<coconnect.io.common.DataBrick object at 0x114a84ee0>]
# 2022-03-09 17:05:50 - LocalDataCollection - INFO - Registering  Serology.csv [<coconnect.io.common.DataBrick object at 0x114a84940>]
# 2022-03-09 17:05:50 - LocalDataCollection - INFO - Registering  Symptoms.csv [<coconnect.io.common.DataBrick object at 0x11511e610>]
# 2022-03-09 17:05:50 - LocalDataCollection - INFO - Registering  Vaccinations.csv [<coconnect.io.common.DataBrick object at 0x11511e8b0>]
# 2022-03-09 17:05:50 - LocalDataCollection - INFO - DataCollection Object Created
# ...
