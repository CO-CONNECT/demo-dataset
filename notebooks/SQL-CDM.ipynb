# %%
import coconnect

# %%
inputs_sql = coconnect.tools.create_sql_store(connection_string="postgresql://localhost:5432/ExampleCOVID19DataSet")
# Out:
# 2022-03-15 09:07:07 - SqlDataCollection - INFO - DataCollection Object Created
# 2022-03-15 09:07:07 - SqlDataCollection - INFO - Engine(postgresql://localhost:5432/ExampleCOVID19DataSet)
# 2022-03-15 09:07:08 - SqlDataCollection - INFO - Registering  person_ids [<coconnect.io.common.DataBrick object at 0x10b4685e0>]
# 2022-03-15 09:07:08 - SqlDataCollection - INFO - Registering  person [<coconnect.io.common.DataBrick object at 0x10b468c70>]
# 2022-03-15 09:07:08 - SqlDataCollection - INFO - Registering  observation [<coconnect.io.common.DataBrick object at 0x10b495940>]
# 2022-03-15 09:07:08 - SqlDataCollection - INFO - Registering  condition_occurrence [<coconnect.io.common.DataBrick object at 0x10b49de50>]
# 2022-03-15 09:07:08 - SqlDataCollection - INFO - Registering  drug_exposure [<coconnect.io.common.DataBrick object at 0x10b4a8d60>]

# %%
cdm = coconnect.cdm.CommonDataModel.load(inputs=inputs_sql)
# Out:
# 2022-03-15 09:07:08 - CommonDataModel - INFO - CommonDataModel (5.3.1) created with co-connect-tools version 0.0.0
# 2022-03-15 09:07:08 - CommonDataModel - INFO - Turning on automatic cdm column filling
# 2022-03-15 09:07:08 - CommonDataModel - WARNING - Not loading person_ids, this is not a valid CDM Table
# 2022-03-15 09:07:08 - SqlDataCollection - INFO - Retrieving initial dataframe for 'person' for the first time
# 2022-03-15 09:07:09 - SqlDataCollection - INFO - Retrieving initial dataframe for 'observation' for the first time
# 2022-03-15 09:07:10 - SqlDataCollection - INFO - Retrieving initial dataframe for 'condition_occurrence' for the first time
# 2022-03-15 09:07:11 - SqlDataCollection - INFO - Retrieving initial dataframe for 'drug_exposure' for the first time
# 2022-03-15 09:07:11 - DrugExposure - WARNING - no objects defined

# %%
cdm.keys()
# Out:
# dict_keys(['person', 'observation', 'condition_occurrence', 'drug_exposure'])

# %%
cdm['person']
# Out:
#            gender_concept_id  year_of_birth  month_of_birth  day_of_birth  \
# person_id
# 1                       8507           1973               7            13
# 2                       8507           1947               7            20
# 3                       8507           1956               7            17
# 4                       8507           1953               7            18
# 5                       8507           1949               7            19
# ...                      ...            ...             ...           ...
# 99509                   8532           1974               7            13
# 99510                   8532           1994               7             8
# 99511                   8532           1971               7            14
# 99512                   8532           1956               7            17
# 99513                   8532           1940               7            21
#
# ...
